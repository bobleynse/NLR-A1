# %%
from osgeo import gdal
import numpy as np
from tifffile import imread, imsave

# %% [markdown]
# # from tif to tif

# %%
tif = imread('images amersfoort/triplesat_20180418_amersfoort.tif')
print(tif.shape)

# remove NIR
rgb_tif = tif[:, :, :-1]
print(rgb_tif.shape)

imsave('rgb1.tif', rgb_tif)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-a77ec18c619b> in <module>()
# ----> 1 tif = imread('images amersfoort/triplesat_20180418_amersfoort.tif')
#       2 print(tif.shape)
#       3
#       4 # remove NIR
#       5 rgb_tif = tif[:, :, :-1]
#
# ~/anaconda3/lib/python3.6/site-packages/tifffile/tifffile.py in imread(files, **kwargs)
#     623
#     624     if isinstance(files, basestring) or hasattr(files, 'seek'):
# --> 625         with TiffFile(files, **kwargs_file) as tif:
#     626             return tif.asarray(**kwargs)
#     627     else:
#
# ~/anaconda3/lib/python3.6/site-packages/tifffile/tifffile.py in __init__(self, arg, name, offset, size, multifile, movie, **kwargs)
#    1923                 raise TypeError('unexpected keyword argument: %s' % key)
#    1924
# -> 1925         fh = FileHandle(arg, mode='rb', name=name, offset=offset, size=size)
#    1926         self._fh = fh
#    1927         self._multifile = bool(multifile)
#
# ~/anaconda3/lib/python3.6/site-packages/tifffile/tifffile.py in __init__(self, file, mode, name, offset, size)
#    5140         self.is_file = False
#    5141         self._lock = NullContext()
# -> 5142         self.open()
#    5143
#    5144     def open(self):
#
# ~/anaconda3/lib/python3.6/site-packages/tifffile/tifffile.py in open(self)
#    5153             self._file = os.path.realpath(self._file)
#    5154             self._dir, self._name = os.path.split(self._file)
# -> 5155             self._fh = open(self._file, self._mode)
#    5156             self._close = True
#    5157             if self._offset is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/rutger/Documents/LerenBeslissen/NLR-A1/TIFF in Python voorbeeld/images amersfoort/triplesat_20180418_amersfoort.tif'

# %% [markdown]
# # from array to tif

# %%
tif = gdal.Open('images amersfoort/triplesat_20180418_amersfoort.tif')

tif_as_array = tif.ReadAsArray()
print(tif_as_array.shape)

# remove NIR
rgb_tif = tif_as_array[:-1, :, :]
print(rgb_tif.shape)

# set shape to (rows,columns,bands)
rgb_tif = rgb_tif.reshape((rgb_tif.shape[1], rgb_tif.shape[2],3))

imsave('rgb2.tif', rgb_tif)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-f6edcc45497f> in <module>()
#       1 tif = gdal.Open('images amersfoort/triplesat_20180418_amersfoort.tif')
#       2
# ----> 3 tif_as_array = tif.ReadAsArray()
#       4 print(tif_as_array.shape)
#       5
#
# AttributeError: 'NoneType' object has no attribute 'ReadAsArray'
